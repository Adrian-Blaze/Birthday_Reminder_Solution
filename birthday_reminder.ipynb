# %%
import pandas as pd
import numpy as np
from datetime import date
import smtplib
from email.mime.text import MIMEText
import os
from dotenv import load_dotenv
from email.mime.multipart import MIMEMultipart

# %%
#t = date.today()
#print(t)

t = date(2024, 6, 1)
print(t)
# Out:
# 2024-06-01

# %%
url = 'https://docs.google.com/spreadsheets/d/140jENzG4GACjso1W9v4Lpl6onnRXZXQ6/export?format=xlsx'

df = pd.read_excel(url)
df
# Out:
#                             Username                     YOUR FULL NAME   \
# 0         ademufrancis1991@gmail.com                      Ademu Francis
# 1         ademufidelis1994@gmail.com              Ademu Fidelis Oshomah
# 2            okekeangel321@gmail.com               Chiemerie Angel okeke
# 3       sucrefashionavenue@gmail.com                    Eke Nancy Ngozi
# 4          preciousonuoha4@gmail.com            Onuoha Precious Cecilia
# 5                irohlucia@gmail.com                  Iroh Lucia Onyinye
# 6           excaliburpablo@gmail.com            Ogoke Francis Uchechukwu
# 7            etonihuchisom@gmail.com          Etonihu Munachiso Assumpta
# 8                tonyemzy1@gmail.com               NWOBODO Anthony Emeka
# 9             atueyichinwe@gmail.com          ATUEYI PRECIOUS CHINWENDU
# 10        kadoanyachinenye@gmail.com           Okafor Chinenye Rosemary
# 11        anisiobinzubechi@gmail.com       Anisiobi Nzubechukwu Anthony
# 12        chiamakamarian26@gmail.com                          Udi Marian
# 13           mimiokonkwo12@gmail.com                    Akanuno nmesoma
# 14               emmy41096@gmail.com             CHUKWU CHIDERA EMMANUEL
# 15           davidemmwnuel@gmail.com                 David Emmanuel John
# 16                jobaluge@gmail.com               Job Izebhokale Aluge
# 17         meckurykingsley@gmail.com                 Madu Emeka Kingsley
# 18         ozohmichael2006@gmail.com            Ozoh Michael Mmaduabuchi
# 19        agbochinecherem9@gmail.com        Agbo Chinecherem Emmanuella
# 20            brunobrowncg@gmail.com                        BRUNO GUBOR
# 21             chikakogolo@gmail.com                     Maryann Okafor
# 22          stephaneapedo2@gmail.com               APEDO KOKOU STEPHANE
# 23              ogebaby652@gmail.com                     Kingsley ogechi
# 24       onuoha.anasthesia@gmail.com             Onuoha chidinma Favour
# 25           lexzymuomah27@gmail.com           Perpetual Chinenye Ademu
# 26          adaeze.joy.779@gmail.com                   Chioma Joy Okeke
# 27          redivy26102006@gmail.com                         Igwe Esther
# 28           florencelucy6@gmail.com                Ibeh Florence Ginika
# 29             rebeccae152@gmail.com                    Rebecca Emmanuel
# 30             ukpongemma2@gmail.com              Ukpong, ( Emmanuel )Â²
# 31          destinymbah112@gmail.com                          MBAH GLORY
# 32              abbypate05@gmail.com                    Omotayo patience
# 33              juliejuliu@gmail.com                      Juliana Julius
# 34        favourcecilia641@gmail.com  Anosike Favour Cecilia Onyinyechi
# 35              ogebaby652@gmail.com                        Kingsley oge
# 36        obinna.b.ukwueze@gmail.com            Obinna Benedict Ukwueze
# 45         Bass                 8066591805            3rd July
# 46         Bass                 7012651467  2008-03-20 00:00:00
# 47          NaN                        NaN                  NaN
#
#    BIRTHDATE(REGULARIZED)  GENDER    STATE OF ORIGIN  \
# 0              2026-02-07    Male                Edo
# 1              2026-04-01    Male         Edo State
# 2              2026-04-29  Female      Anambra state
# 3              2026-05-04  Female         Abia state
# 4              2026-05-01  Female         Abia state
# 5              2026-05-13  Female          Imo state
# 6              2026-03-05    Male                Imo
# 7              2026-08-28  Female         Imo state
# 8              2026-07-02    Male             Enugu
# 9              2026-11-13  Female         IMO STATE
# 10             2026-05-18  Female        Delta state
# 11             2026-04-18    Male           Anambra
# 12             2026-01-07  Female                Imo
# 13             2026-06-24  Female     Anambra state
# 14             2026-12-01    Male              ENUGU
# 15             2026-06-01    Male       Ebonyi state
# 16             2026-07-16    Male                Edo
# 17             2026-10-25    Male                Imo
# 18             2026-10-12    Male            Anambra
# 19             2026-06-13  Female        Enugu State
# 20             2026-02-20    Male                IMO
# 21             2026-05-10  Female             Delta
# 22             2026-10-02    Male             ECOWAS
# 23             2026-08-21  Female        Enugu State
# 24             2026-06-18  Female        Abia state
# 25             2026-04-27  Female      Anambra State
# 26             2026-06-15  Female     Anambra State
# 27             2026-10-26  Female         Abia State
# 28             2026-11-11  Female                Imo
# 29             2026-10-11  Female          Akwa ibom
# 30             2026-05-01    Male   Akwa-Ibom state
# 31             2026-11-11  Female  CROSS RIVER STATE
# 32             2005-05-01  Female         Ondo state
# 33             2011-10-01  Female          Edo state
# 34             2026-11-10  Female          Imo State
# 35             2026-08-21  Female             Ebonyi
# 36             2026-07-02    Male        Enugu state
# 37             2026-05-13  Female                Imo
# 38             2026-06-15  Female      Anambra state
# 39                    NaT  Female                Imo
# 40             2026-12-01    Male              ENUGU
# 41             2026-06-15  Female     Anambra state
# 42             2026-01-20  Female           Anambra
# 43             2026-10-04  Female               Abia
# 44             2026-04-23  Female             Enugu
# 45             2026-07-03    Male             Enugu
# 46             2026-03-20    Male         Imo state
# 47             2026-04-06     NaN                NaN
#
#                           WHY DID YOU JOIN THE CHOIR? START DATE WITH CHOIR
# 0                       To serve God through singing    2015-08-01 00:00:00
# 1                       I joined because I love music   2019-10-16 00:00:00
# 2   \n"I joined the choir because I'm passionate a...   2022-09-20 00:00:00
# 3                               The love for singing    2024-08-30 00:00:00
# 4   That's because of their unique performance dur...   2017-06-18 00:00:00
# 5                                 Cos I love singing    2020-02-19 00:00:00
# 6                                    To sing for God.   2017-03-16 00:00:00
# 7   I joined the choir because I love singing and ...   2011-07-17 00:00:00
# 8                              For the love of music    2013-01-10 00:00:00
# 9                               Because I love music    2023-11-19 00:00:00
# 10  Cause i love to sing and to render my service ...   2024-08-30 00:00:00
# 11                      Was drawn to chorale harmony.   2019-01-06 00:00:00
# 13             2026-06-24                    Akanuno nmesoma
# 14             2026-12-01             CHUKWU CHIDERA EMMANUEL
# 15             2026-06-01                 David Emmanuel John
# 16             2026-07-16               Job Izebhokale Aluge
# 17             2026-10-25                 Madu Emeka Kingsley
# 18             2026-10-12            Ozoh Michael Mmaduabuchi
# 19             2026-06-13        Agbo Chinecherem Emmanuella
# 20             2026-02-20                        BRUNO GUBOR
# 21             2026-05-10                     Maryann Okafor
# 22             2026-10-02               APEDO KOKOU STEPHANE
# 23             2026-08-21                     Kingsley ogechi
# 24             2026-06-18             Onuoha chidinma Favour
# 25             2026-04-27           Perpetual Chinenye Ademu
# 26             2026-06-15                   Chioma Joy Okeke
# 27             2026-10-26                         Igwe Esther
# 28             2026-11-11                Ibeh Florence Ginika
# 29             2026-10-11                    Rebecca Emmanuel
# 30             2026-05-01              Ukpong, ( Emmanuel )Â²
# 31             2026-11-11                          MBAH GLORY
# 32             2005-05-01                    Omotayo patience
# 33             2011-10-01                      Juliana Julius
# 34             2026-11-10  Anosike Favour Cecilia Onyinyechi
# 35             2026-08-21                        Kingsley oge
# 36             2026-07-02            Obinna Benedict Ukwueze
# 37             2026-05-13                     Onyinyechi Lucy
# 38             2026-06-15                    Chioma Joy Okeke
# 39                    NaT        Nwaiwu Christianah Ordinakah
# 40             2026-12-01            CHUKWU CHIDERA EMMANUEL
# 41             2026-06-15                     Onwuasoeze joy
# 42             2026-01-20               Nwenyi Victory ngozi
# 43             2026-10-04               Igwe Ifunanya Vivian
# 44             2026-04-23                      MRS EZE CHIOMA
# 45             2026-07-03                       MR EZE FABIAN
# 46             2026-03-20           Gilbert munachimso Elvis
# 47             2026-04-06                                Kyle

# %%
load_dotenv()
EMAIL_ADDRESS = os.getenv('Email_Address')
EMAIL_PASSWORD = os.getenv('Email_Password')
SMTP_SERVER = 'smtp.gmail.com'
PORT = 587

def send_birthday_email(recipient_email, subject, body):
    msg = MIMEMultipart()
    msg['From'] = EMAIL_ADDRESS
    msg['To'] = recipient_email
    msg['Subject'] = subject
    
    msg.attach(MIMEText(body, 'plain'))
    
    try:
        with smtplib.SMTP(SMTP_SERVER, PORT) as server:
            server.starttls()
            server.login(EMAIL_ADDRESS, EMAIL_PASSWORD)
            server.sendmail(EMAIL_ADDRESS, recipient_email, msg.as_string())
        print(f'Email sent sucessfully')
    except Exception as e:
        print(f'Failed to send email: {e}')

# %%
recipient = 'anisiobinzubechi@gmail.com'
subject = 'Birthday Reminder!'

# %%
for index, row in df.iterrows():
    birthdate = row['BIRTHDATE(REGULARIZED)']
    name = row['YOUR FULL NAME ']
    
    if birthdate.month == t.month and birthdate.day == t.day:
        print(f"Today is {name}'s birthday!")
        body = f"Today is {name}'s birthday!"
        
        send_birthday_email (recipient, subject, body)
# Out:
# Today is David Emmanuel John's birthday!
# Failed to send email: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
